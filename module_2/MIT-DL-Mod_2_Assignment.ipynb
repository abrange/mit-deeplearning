# %% [markdown]
# # *Module 2 Assignment*

# %% [markdown]
# ## Download Data

# %%
## Data: Download required files
# Download the wine .csv files from data archive

# !rm -f winequality-red.csv winequality-white.csv
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv
# Out:
# 6946.48s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 6951.72s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# --2025-07-06 23:45:47--  https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘winequality-red.csv’
#
# winequality-red.csv     [ <=>                ]  82.23K  --.-KB/s    in 0.1s
#
# 2025-07-06 23:45:47 (721 KB/s) - ‘winequality-red.csv’ saved [84199]
# 6957.19s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# --2025-07-06 23:45:53--  https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘winequality-white.csv’
#
# winequality-white.c     [  <=>               ] 258.23K   856KB/s    in 0.3s
#
# 2025-07-06 23:45:53 (856 KB/s) - ‘winequality-white.csv’ saved [264426]

# %% [markdown]
# ## Prepare Data

# %%
# These are the packages required for this assignment
import pandas as pd
import numpy as np

# Use Pandas to read the csv file into a dataframe.
# Note that the delimiter in this csv is the semicolon ";" instead of a ,
df_red = pd.read_csv('winequality-red.csv',delimiter=";")

# Because we are performing a classification task, we will assign all red wine a label of 1

df_red["color"] = 1

# The method .head() is super useful for seeing a preview of our data!
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  color
# 0      9.4        5      1
# 1      9.8        5      1
# 2      9.8        5      1
# 3      9.8        6      1
# 4      9.4        5      1

# %%
df_white = pd.read_csv('winequality-white.csv',delimiter=";")
df_white["color"] = 0  #assign white wine the label 0
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6      0
# 1      9.5        6      0
# 2     10.1        6      0
# 3      9.9        6      0
# 4      9.9        6      0

# %%
# Now we combine our two dataframes
df = pd.concat([df_red, df_white])

# And shuffle them in place to mix the red and white wine data together
df = df.sample(frac=1).reset_index(drop=True)

SEED_ =  42
# Define the split ratio
test_size = 0.10
# For reproducibility
np.random.seed(SEED_)

# Sample 20% of the data for the test set
# frac=test_size specifies the fraction of rows to return
# random_state ensures reproducibility
test_df = df.sample(frac=test_size, random_state=SEED_)

# The remaining data will be the training set
# We drop the indices that are in the test set from the original DataFrame
train_df = df.drop(test_df.index)

print("Train DataFrame shape:", train_df.shape)
print("Test DataFrame shape:", test_df.shape)
print("\n")

# Separate in Train and Test Set. Train: 80% and Test 20%
train_df.head()
# Out:
# Train DataFrame shape: (5847, 13)
# Test DataFrame shape: (650, 13)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.7              0.46         0.24             1.7      0.077
# 1            8.0              0.57         0.39             3.9      0.034
# 2            7.6              0.27         0.33             2.0      0.059
# 3            6.8              0.21         0.31             2.9      0.046
# 4            6.0              0.20         0.26             6.8      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 18.0                  34.0   0.9948  3.39       0.60
# 1                 22.0                 122.0   0.9917  3.29       0.67
# 2                 19.0                 175.0   0.9944  3.22       0.56
# 3                 40.0                 121.0   0.9913  3.07       0.65
# 4                 22.0                  93.0   0.9928  3.15       0.42
#
#    alcohol  quality  color
# 0     10.6        6      1
# 1     12.8        7      0
# 2      9.9        5      0
# 3     10.9        7      0
# 4     11.0        6      0

# %%
# We choose three attributes of the wine to perform our prediction on
input_columns = ["citric acid", "residual sugar", "total sulfur dioxide"]
output_columns = ["color"]

# We extract the relevant features into our X and Y numpy arrays
X = train_df[input_columns].to_numpy()
Y = train_df[output_columns].to_numpy()
print("Shape of X:", X.shape)
print("Shape of Y:", Y.shape)
in_features = X.shape[1]
# Out:
# Shape of X: (5847, 3)
# Shape of Y: (5847, 1)

# %% [markdown]
# ### Define Model

# %%
import random
import math

class MyWineModel():
    def __init__(self, num_features, activation_function, do_print=False):
        self.w_0 = random.gauss(0,1)
        self.w = [random.gauss(0,1) for _ in range(num_features)]
        self.activation = activation_function
        self.do_print = do_print
    
    def forward(self, x):
        # Perform the dot product on the input x and the learned weights w
        z = 0
        for feature, weight in zip(x, self.w):
            z += feature * weight
        z += self.w_0  #Add the bias term
    
        # Apply the activation function, and return
        a = self.activation(z) #Example: sigmoid(z)
        return a

    # Training process, using negative log likelihood (NLL) loss --
    # appropriate for classification problems
    def train_model_NLL_loss(
            self,
            input_data,
            output_data,
            learning_rate,
            num_epochs):
        
        non_zero_tolerance = 1e-8 # add this to log calculations to ensure we don't take the log of 0
        for epoch in range(num_epochs):
            total_loss = 0 #keep track of total loss across the data set
            for x, y in zip(input_data, output_data):
                y_predicted = self.forward(x)
                nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
    
                total_loss += nll_loss
                if self.do_print: print("x:", x, "y:", y, "nll_loss:", nll_loss)
                if self.do_print: print(" old weights:", self.w, self.w_0)
    
                # update bias coefficent using gradient w.r.t w_0
                self.w_0 -= learning_rate * (y_predicted - y)
    
                # update other model coefficients using gradient w.r.t that coeff
                for j, x_j in enumerate(x):
                    self.w[j] -= learning_rate * (y_predicted - y) * x_j
    
                if self.do_print: print(" new weights:", self.w,self.w_0)
    
            report_every = max(1, num_epochs // 10)
            if epoch % report_every == 0: #every few epochs, report on progress
                print("w_0:", self.w_0, "w", self.w)
                print("epoch", epoch, "has total loss", total_loss)

        return self.w, self.w_0
    
    # sigmoid activation function; squashes a real value z to between 0 and 1
    @staticmethod 
    def sigmoid(z):
        non_zero_tolerance = 1e-8 # add this to divisions to ensure we don't divide by 0
        return 1 / (1 + np.exp(-z) + non_zero_tolerance)

    # simple linear activation function: it just returns identity
    # AB Note: An identity function, is a function that returns the same input without modifing it.
    # example: f(x) = x
    @staticmethod
    def linear(z):
        return z

# %%
#test model
model = MyWineModel(3, MyWineModel.sigmoid)
model.train_model_NLL_loss(X, Y, 0.00005, 500)
# Out:
# w_0: [0.25024985] w [array([0.79222442]), array([-0.51689902]), array([-0.00427752])]
# epoch 0 has total loss [3452.16332545]
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_60394/2714061688.py:62: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return 1 / (1 + math.exp(-z) + non_zero_tolerance)
# w_0: [1.18973744] w [array([0.95857281]), array([-0.0038768]), array([-0.02716417])]
# epoch 50 has total loss [1701.59651356]
# w_0: [1.80429218] w [array([1.04067214]), array([-0.02183795]), array([-0.03223671])]
# epoch 100 has total loss [1548.40847521]
# w_0: [2.25021675] w [array([1.08192872]), array([-0.03574106]), array([-0.03612989])]
# epoch 150 has total loss [1469.6729979]
# w_0: [2.59130622] w [array([1.0989432]), array([-0.04670714]), array([-0.03920938])]
# epoch 200 has total loss [1424.50503633]
# w_0: [2.86205057] w [array([1.10035921]), array([-0.0555424]), array([-0.04169913])]
# epoch 250 has total loss [1396.48747795]
# w_0: [3.08278477] w [array([1.09113399]), array([-0.06278953]), array([-0.04374584])]
# epoch 300 has total loss [1378.0733613]
# w_0: [3.26638997] w [array([1.07434115]), array([-0.06882015]), array([-0.04545023])]
# epoch 350 has total loss [1365.41307429]
# w_0: [3.42150283] w [array([1.05200601]), array([-0.07389666]), array([-0.04688413])]
# epoch 400 has total loss [1356.38130857]
# w_0: [3.55418115] w [array([1.02552846]), array([-0.07821006]), array([-0.04810036])]
# epoch 450 has total loss [1349.73082393]
# ([array([0.99653148]), array([-0.08183458]), array([-0.04911958])],
#  array([3.66669146]))

# %%
# Your Code Here!
# classification_model = ...
classification_model = MyWineModel(3, MyWineModel.sigmoid)
classification_model.train_model_NLL_loss(X, Y, 0.001, 200)

#...

# We will use this function to evaluate how well our trained classifier perfom
# Hint: the model you define above must have a .forward function in order to be compatible
# Hint: this evaluation function is identical to those in previous notebooks
def evaluate_classification_accuracy(model, input_data, labels):
    # Count the number of correctly classified samples given a set of weights
    correct = 0
    num_samples = len(input_data)
    for i in range(num_samples):
        x = input_data[i,...]
        y = labels[i]
        y_predicted = model.forward(x)
        label_predicted = 1 if y_predicted > 0.5 else 0
        if label_predicted == y:
            correct += 1
    accuracy = correct / num_samples
    print("Our model predicted", correct, "out of", num_samples,
          "correctly for", accuracy*100, "% accuracy")
    return accuracy
# Out:
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_64994/91014166.py:36: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 # Your Code Here!
#       3 # classification_model = ...
#       4 classification_model = MyWineModel(3, MyWineModel.sigmoid)
# ----> 5 classification_model.train_model_NLL_loss(X, Y, 0.001, 200)
#       7 #...
#       8
#       9 # We will use this function to evaluate how well our trained classifier perfom
#      10 # Hint: the model you define above must have a .forward function in order to be compatible
#      11 # Hint: this evaluation function is identical to those in previous notebooks
#      12 def evaluate_classification_accuracy(model, input_data, labels):
#      13     # Count the number of correctly classified samples given a set of weights
#
# Cell In[5], line 35, in MyWineModel.train_model_NLL_loss(self, input_data, output_data, learning_rate, num_epochs)
#      33 total_loss = 0 #keep track of total loss across the data set
#      34 for x, y in zip(input_data, output_data):
# ---> 35     y_predicted = self.forward(x)
#      36     nll_loss = -(y * math.log(y_predicted + non_zero_tolerance) + (1-y) * math.log(1-y_predicted + non_zero_tolerance))
#      38     total_loss += nll_loss
#
# Cell In[5], line 19, in MyWineModel.forward(self, x)
#      16 z += self.w_0  #Add the bias term
#      18 # Apply the activation function, and return
# ---> 19 a = self.activation(z) #Example: sigmoid(z)
#      20 return a
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1470, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1512, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1313, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1950, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File /opt/miniconda3/envs/DL/lib/python3.13/site-packages/debugpy/_vendored/pydevd/pydevd.py:2188, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2185             from_this_thread.append(frame_custom_thread_id)
#    2187     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2188         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2190 frames_list = None
#    2192 if keep_suspended:
#    2193     # This means that we should pause again after a set next statement.
#
# File /opt/miniconda3/envs/DL/lib/python3.13/site-packages/debugpy/_vendored/pydevd/pydevd.py:2257, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2254                 queue.put(internal_cmd)
#    2255                 wait_timeout = TIMEOUT_FAST
# -> 2257         notify_event.wait(wait_timeout)
#    2258         notify_event.clear()
#    2260 finally:
#
# File /opt/miniconda3/envs/DL/lib/python3.13/threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File /opt/miniconda3/envs/DL/lib/python3.13/threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
X_test = test_df[input_columns].to_numpy()
Y_test = test_df[output_columns].to_numpy()

evaluate_classification_accuracy(
    model=model,
    input_data=X_test,
    labels=Y_test)
# Out:
# Our model predicted 598 out of 650 correctly for 92.0 % accuracy
# /var/folders/py/v9v9t_b10v7czff5wz1rwswc0000gn/T/ipykernel_60394/2714061688.py:62: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return 1 / (1 + math.exp(-z) + non_zero_tolerance)
# 0.92
